# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoVal1/Model_for_prediciting_sentiments/blob/main/Model_for_predicting_sentiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##MODEL FOR PREDICTING SENTIMENTS

# %% [markdown]
# In this colab, you use different kinds of layers to see how they affect the model.
#
# You will use the glue/sst2 dataset, which is available through tensorflow_datasets.
#
# The General Language Understanding Evaluation (GLUE) benchmark (https://gluebenchmark.com/) is a collection of resources for training, evaluating, and analyzing natural language understanding systems.
#
# These resources include the Stanford Sentiment Treebank (SST) dataset that consists of sentences from movie reviews and human annotations of their sentiment. This colab uses version 2 of the SST dataset.
#
# The splits are:
#
# *   train	67,349
# *   validation	872
#
#
# and the column headings are:
#
# *   sentence
# *   label
#
#
# For more information about the dataset, see [https://www.tensorflow.org/datasets/catalog/glue#gluesst2](https://www.tensorflow.org/datasets/catalog/glue#gluesst2)

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

import numpy as np

# %% [markdown]
# # Get the dataset

# %%
# Get the dataset.
# It has 70000 items, so might take a while to download
dataset, info = tfds.load('glue/sst2', with_info=True)
print(info.features)
print(info.features["label"].num_classes)
print(info.features["label"].names)
# Out:
# Downloading and preparing dataset 7.09 MiB (download: 7.09 MiB, generated: 7.22 MiB, total: 14.31 MiB) to ~/tensorflow_datasets/glue/sst2/2.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/67349 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/glue/sst2/2.0.0.incompleteX0RSGE/glue-train.tfrecord*...:   0%|          | 0/6…
# Generating validation examples...:   0%|          | 0/872 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/glue/sst2/2.0.0.incompleteX0RSGE/glue-validation.tfrecord*...:   0%|          …
# Generating test examples...:   0%|          | 0/1821 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/glue/sst2/2.0.0.incompleteX0RSGE/glue-test.tfrecord*...:   0%|          | 0/18…
# Dataset glue downloaded and prepared to ~/tensorflow_datasets/glue/sst2/2.0.0. Subsequent calls will reuse this data.
# FeaturesDict({
#     'idx': tf.int32,
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=2),
#     'sentence': Text(shape=(), dtype=tf.string),
# })
# 2
# ['negative', 'positive']

# %%
# Get the training and validation datasets
dataset_train, dataset_validation = dataset['train'], dataset['validation']
dataset_train
# Out:
# <PrefetchDataset element_spec={'idx': TensorSpec(shape=(), dtype=tf.int32, name=None), 'label': TensorSpec(shape=(), dtype=tf.int64, name=None), 'sentence': TensorSpec(shape=(), dtype=tf.string, name=None)}>

# %%
# Print some of the entries
for example in dataset_train.take(2):  
  review, label = example["sentence"], example["label"]
  print("Review:", review)
  print("Label: %d \n" % label.numpy())
# Out:
# Review: tf.Tensor(b'for the uninitiated plays better on video with the sound ', shape=(), dtype=string)
# Label: 0
#
# Review: tf.Tensor(b'like a giant commercial for universal studios , where much of the action takes place ', shape=(), dtype=string)
# Label: 0

# %%
# Get the sentences and the labels
# for both the training and the validation sets
training_reviews = []
training_labels = []
 
validation_reviews = []
validation_labels = []

# The dataset has 67,000 training entries, but that's a lot to process here!

# If you want to take the entire dataset: WARNING: takes longer!!
# for item in dataset_train.take(-1):

# Take 10,000 reviews
for item in dataset_train.take(10000):
  review, label = item["sentence"], item["label"]
  training_reviews.append(str(review.numpy()))
  training_labels.append(label.numpy())

print ("\nNumber of training reviews is: ", len(training_reviews))

# print some of the reviews and labels
for i in range(0, 2):
  print (training_reviews[i])
  print (training_labels[i])

# Get the validation data
# there's only about 800 items, so take them all
for item in dataset_validation.take(-1):  
  review, label = item["sentence"], item["label"]
  validation_reviews.append(str(review.numpy()))
  validation_labels.append(label.numpy())

print ("\nNumber of validation reviews is: ", len(validation_reviews))

# Print some of the validation reviews and labels
for i in range(0, 2):
  print (validation_reviews[i])
  print (validation_labels[i])
# Out:
# Number of training reviews is:  10000
# b'for the uninitiated plays better on video with the sound '
# 0
# b'like a giant commercial for universal studios , where much of the action takes place '
# 0
#
# Number of validation reviews is:  872
# b'a valueless kiddie paean to pro basketball underwritten by the nba . '
# 0
# b"featuring a dangerously seductive performance from the great daniel auteuil , `` sade '' covers the same period as kaufmann 's `` quills '' with more unsettlingly realistic results . "
# 1

# %% [markdown]
# # Tokenize the words and sequence the sentences

# %%
# There's a total of 21224 words in the reviews
# but many of them are irrelevant like with, it, of, on.
# If we take a subset of the training data, then the vocab
# will be smaller.

# A reasonable review might have about 50 words or so,
# so we can set max_length to 50 (but feel free to change it as you like)

vocab_size = 4000
embedding_dim = 16
max_length = 50
trunc_type='post'
pad_type='post'
oov_tok = "<OOV>"

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_reviews)
word_index = tokenizer.word_index

# %% [markdown]
# # Pad the sequences

# %%
# Pad the sequences so that they are all the same length
training_sequences = tokenizer.texts_to_sequences(training_reviews)
training_padded = pad_sequences(training_sequences,maxlen=max_length, 
                                truncating=trunc_type, padding=pad_type)

validation_sequences = tokenizer.texts_to_sequences(validation_reviews)
validation_padded = pad_sequences(validation_sequences,maxlen=max_length)

training_labels_final = np.array(training_labels)
validation_labels_final = np.array(validation_labels)

# %% [markdown]
# # Create the model using an Embedding

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),  
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 16)            64000
#
#  global_average_pooling1d (G  (None, 16)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 64,017
# Trainable params: 64,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the model

# %%
num_epochs = 20
history = model.fit(training_padded, training_labels_final, epochs=num_epochs, 
                    validation_data=(validation_padded, validation_labels_final))
# Out:
# Epoch 1/20
# 313/313 [==============================] - 2s 3ms/step - loss: 0.6823 - accuracy: 0.5598 - val_loss: 0.6896 - val_accuracy: 0.5126
# Epoch 2/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6713 - accuracy: 0.5780 - val_loss: 0.6717 - val_accuracy: 0.5952
# Epoch 3/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6520 - accuracy: 0.6207 - val_loss: 0.6475 - val_accuracy: 0.6479
# Epoch 4/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6250 - accuracy: 0.6689 - val_loss: 0.6182 - val_accuracy: 0.6904
# Epoch 5/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5929 - accuracy: 0.7040 - val_loss: 0.5874 - val_accuracy: 0.7271
# Epoch 6/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5600 - accuracy: 0.7395 - val_loss: 0.5588 - val_accuracy: 0.7248
# Epoch 7/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5276 - accuracy: 0.7682 - val_loss: 0.5351 - val_accuracy: 0.7397
# Epoch 8/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4987 - accuracy: 0.7898 - val_loss: 0.5179 - val_accuracy: 0.7511
# Epoch 9/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4719 - accuracy: 0.8051 - val_loss: 0.5054 - val_accuracy: 0.7534
# Epoch 10/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4482 - accuracy: 0.8194 - val_loss: 0.4979 - val_accuracy: 0.7500
# Epoch 11/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4270 - accuracy: 0.8288 - val_loss: 0.4881 - val_accuracy: 0.7592
# Epoch 12/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4080 - accuracy: 0.8355 - val_loss: 0.4849 - val_accuracy: 0.7626
# Epoch 13/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3908 - accuracy: 0.8440 - val_loss: 0.4869 - val_accuracy: 0.7603
# Epoch 14/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3756 - accuracy: 0.8470 - val_loss: 0.4852 - val_accuracy: 0.7672
# Epoch 15/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3625 - accuracy: 0.8511 - val_loss: 0.4855 - val_accuracy: 0.7718
# Epoch 16/20
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3493 - accuracy: 0.8573 - val_loss: 0.4930 - val_accuracy: 0.7683
# Epoch 17/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3376 - accuracy: 0.8617 - val_loss: 0.4983 - val_accuracy: 0.7683
# Epoch 18/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3270 - accuracy: 0.8645 - val_loss: 0.5032 - val_accuracy: 0.7729
# Epoch 19/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3168 - accuracy: 0.8683 - val_loss: 0.5112 - val_accuracy: 0.7661
# Epoch 20/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3081 - accuracy: 0.8721 - val_loss: 0.5193 - val_accuracy: 0.7695

# %% [markdown]
# # Plot the accurracy and loss

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# # Write a function to predict the sentiment of reviews

# %%
# Write some new reviews 

review1 = """I loved this movie"""

review2 = """that was the worst movie I've ever seen"""

review3 = """too much violence even for a Bond film"""

review4 = """a captivating recounting of a cherished myth"""

new_reviews = [review1, review2, review3, review4]

# %%
# Define a function to prepare the new reviews for use with a model
# and then use the model to predict the sentiment of the new reviews           

def predict_review(model, reviews):
  # Create the sequences
  padding_type='post'
  sample_sequences = tokenizer.texts_to_sequences(reviews)
  reviews_padded = pad_sequences(sample_sequences, padding=padding_type, 
                                 maxlen=max_length) 
  classes = model.predict(reviews_padded)
  for x in range(len(reviews_padded)):
    print(reviews[x])
    print(classes[x])
    print('\n')

predict_review(model, new_reviews)
# Out:
# I loved this movie
# [0.39298257]
#
#
# that was the worst movie I've ever seen
# [0.11397702]
#
#
# too much violence even for a Bond film
# [0.0312542]
#
#
# a captivating recounting of a cherished myth
# [0.59909594]

# %% [markdown]
# # Define a function to train and show the results of models with different layers

# %%
def fit_model_and_show_results (model, reviews):
  model.summary()
  history = model.fit(training_padded, training_labels_final, epochs=num_epochs, 
                      validation_data=(validation_padded, validation_labels_final))
  plot_graphs(history, "accuracy")
  plot_graphs(history, "loss")
  predict_review(model, reviews)

# %% [markdown]
# # Use a CNN

# %%
num_epochs = 30

model_cnn = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(16, 5, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Default learning rate for the Adam optimizer is 0.001
# Let's slow down the learning rate by 10.
learning_rate = 0.0001
model_cnn.compile(loss='binary_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate), 
                  metrics=['accuracy'])

fit_model_and_show_results(model_cnn, new_reviews)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 50, 16)            64000
#
#  conv1d (Conv1D)             (None, 46, 16)            1296
#
#  global_max_pooling1d (Globa  (None, 16)               0
#  lMaxPooling1D)
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 65,313
# Trainable params: 65,313
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 313/313 [==============================] - 2s 4ms/step - loss: 0.6911 - accuracy: 0.5381 - val_loss: 0.6915 - val_accuracy: 0.5172
# Epoch 2/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6830 - accuracy: 0.5663 - val_loss: 0.6911 - val_accuracy: 0.5092
# Epoch 3/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6776 - accuracy: 0.5598 - val_loss: 0.6894 - val_accuracy: 0.5092
# Epoch 4/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6714 - accuracy: 0.5648 - val_loss: 0.6856 - val_accuracy: 0.5138
# Epoch 5/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6629 - accuracy: 0.5827 - val_loss: 0.6790 - val_accuracy: 0.5814
# Epoch 6/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6506 - accuracy: 0.6452 - val_loss: 0.6691 - val_accuracy: 0.6411
# Epoch 7/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6335 - accuracy: 0.6952 - val_loss: 0.6554 - val_accuracy: 0.6835
# Epoch 8/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6111 - accuracy: 0.7367 - val_loss: 0.6383 - val_accuracy: 0.7076
# Epoch 9/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5838 - accuracy: 0.7661 - val_loss: 0.6194 - val_accuracy: 0.7167
# Epoch 10/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5528 - accuracy: 0.7894 - val_loss: 0.5998 - val_accuracy: 0.7248
# Epoch 11/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5207 - accuracy: 0.8064 - val_loss: 0.5806 - val_accuracy: 0.7248
# Epoch 12/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4888 - accuracy: 0.8166 - val_loss: 0.5652 - val_accuracy: 0.7385
# Epoch 13/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4588 - accuracy: 0.8300 - val_loss: 0.5494 - val_accuracy: 0.7408
# Epoch 14/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4309 - accuracy: 0.8379 - val_loss: 0.5365 - val_accuracy: 0.7511
# Epoch 15/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4059 - accuracy: 0.8460 - val_loss: 0.5233 - val_accuracy: 0.7466
# Epoch 16/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3836 - accuracy: 0.8537 - val_loss: 0.5131 - val_accuracy: 0.7511
# Epoch 17/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3637 - accuracy: 0.8574 - val_loss: 0.5080 - val_accuracy: 0.7569
# Epoch 18/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3460 - accuracy: 0.8656 - val_loss: 0.5006 - val_accuracy: 0.7638
# Epoch 19/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3302 - accuracy: 0.8704 - val_loss: 0.4972 - val_accuracy: 0.7615
# Epoch 20/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3160 - accuracy: 0.8739 - val_loss: 0.4944 - val_accuracy: 0.7592
# Epoch 21/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3029 - accuracy: 0.8775 - val_loss: 0.4922 - val_accuracy: 0.7661
# Epoch 22/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2914 - accuracy: 0.8826 - val_loss: 0.4933 - val_accuracy: 0.7638
# Epoch 23/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2807 - accuracy: 0.8856 - val_loss: 0.4932 - val_accuracy: 0.7626
# Epoch 24/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2710 - accuracy: 0.8896 - val_loss: 0.4965 - val_accuracy: 0.7661
# Epoch 25/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2618 - accuracy: 0.8918 - val_loss: 0.5002 - val_accuracy: 0.7672
# Epoch 26/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2532 - accuracy: 0.8956 - val_loss: 0.5021 - val_accuracy: 0.7626
# Epoch 27/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2453 - accuracy: 0.8973 - val_loss: 0.5074 - val_accuracy: 0.7615
# Epoch 28/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2380 - accuracy: 0.8997 - val_loss: 0.5136 - val_accuracy: 0.7638
# Epoch 29/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2310 - accuracy: 0.9031 - val_loss: 0.5192 - val_accuracy: 0.7615
# Epoch 30/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2246 - accuracy: 0.9046 - val_loss: 0.5247 - val_accuracy: 0.7638
# I loved this movie
# [0.89230514]
#
#
# that was the worst movie I've ever seen
# [0.11086819]
#
#
# too much violence even for a Bond film
# [0.00700977]
#
#
# a captivating recounting of a cherished myth
# [0.7688199]

# %% [markdown]
# # Use a GRU

# %%
num_epochs = 30

model_gru = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.00003 # slower than the default learning rate
model_gru.compile(loss='binary_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate),
                  metrics=['accuracy'])

fit_model_and_show_results(model_gru, new_reviews)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 50, 16)            64000
#
#  bidirectional (Bidirectiona  (None, 64)               9600
#  l)
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params:
30
# 313/313 [==============================] - 11s 37ms/step - loss: 0.3644 - accuracy: 0.8460 - val_loss: 0.5770 - val_accuracy: 0.7546
# Epoch 28/30
# 313/313 [==============================] - 12s 37ms/step - loss: 0.3573 - accuracy: 0.8498 - val_loss: 0.5841 - val_accuracy: 0.7546
# Epoch 29/30
# 313/313 [==============================] - 11s 36ms/step - loss: 0.3497 - accuracy: 0.8515 - val_loss: 0.6016 - val_accuracy: 0.7523
# Epoch 30/30
# 313/313 [==============================] - 11s 37ms/step - loss: 0.3443 - accuracy: 0.8552 - val_loss: 0.5939 - val_accuracy: 0.7569
# I loved this movie
# [0.32185858]
#
#
# that was the worst movie I've ever seen
# [0.1261791]
#
#
# too much violence even for a Bond film
# [0.0750429]
#
#
# a captivating recounting of a cherished myth
# [0.5913255]

# %% [markdown]
# # Add a bidirectional LSTM

# %%
num_epochs = 30

model_bidi_lstm = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim)), 
    tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.00003
model_bidi_lstm.compile(loss='binary_crossentropy',
                        optimizer=tf.keras.optimizers.Adam(learning_rate),
                        metrics=['accuracy'])
fit_model_and_show_results(model_bidi_lstm, new_reviews)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 50, 16)            64000
#
#  bidirectional_1 (Bidirectio  (None, 32)               4224
#  nal)
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 68,257
# Trainable params: 68,257
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 313/313 [==============================] - 16s 33ms/step - loss: 0.6912 - accuracy: 0.5488 - val_loss: 0.6931 - val_accuracy: 0.5092
# Epoch 2/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.6873 - accuracy: 0.5590 - val_loss: 0.6941 - val_accuracy: 0.5092
# Epoch 3/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.6850 - accuracy: 0.5590 - val_loss: 0.6955 - val_accuracy: 0.5092
# Epoch 4/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.6834 - accuracy: 0.5590 - val_loss: 0.6973 - val_accuracy: 0.5092
# Epoch 5/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.6821 - accuracy: 0.5590 - val_loss: 0.6988 - val_accuracy: 0.5092
# Epoch 6/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.6805 - accuracy: 0.5590 - val_loss: 0.7007 - val_accuracy: 0.5092
# Epoch 7/30
# 313/313 [==============================] - 11s 34ms/step - loss: 0.6783 - accuracy: 0.5590 - val_loss: 0.7025 - val_accuracy: 0.5092
# Epoch 8/30
# 313/313 [==============================] - 11s 35ms/step - loss: 0.6757 - accuracy: 0.5590 - val_loss: 0.7059 - val_accuracy: 0.5092
# Epoch 9/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.6725 - accuracy: 0.5591 - val_loss: 0.7118 - val_accuracy: 0.5092
# Epoch 10/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.6686 - accuracy: 0.5637 - val_loss: 0.7155 - val_accuracy: 0.5092
# Epoch 11/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.6641 - accuracy: 0.5805 - val_loss: 0.7195 - val_accuracy: 0.5092
# Epoch 12/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.6589 - accuracy: 0.6012 - val_loss: 0.7279 - val_accuracy: 0.5092
# Epoch 13/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.6530 - accuracy: 0.6187 - val_loss: 0.7290 - val_accuracy: 0.5092
# Epoch 14/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.6463 - accuracy: 0.6388 - val_loss: 0.7366 - val_accuracy: 0.5092
# Epoch 15/30
# 313/313 [==============================] - 11s 35ms/step - loss: 0.6382 - accuracy: 0.6472 - val_loss: 0.7353 - val_accuracy: 0.5092
# Epoch 16/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.6282 - accuracy: 0.6576 - val_loss: 0.7299 - val_accuracy: 0.5069
# Epoch 17/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.6159 - accuracy: 0.6693 - val_loss: 0.7298 - val_accuracy: 0.5069
# Epoch 18/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.6011 - accuracy: 0.6798 - val_loss: 0.7191 - val_accuracy: 0.5080
# Epoch 19/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.5844 - accuracy: 0.6969 - val_loss: 0.7025 - val_accuracy: 0.5092
# Epoch 20/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.5675 - accuracy: 0.7184 - val_loss: 0.6884 - val_accuracy: 0.5126
# Epoch 21/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.5517 - accuracy: 0.7330 - val_loss: 0.6715 - val_accuracy: 0.5103
# Epoch 22/30
# 313/313 [==============================] - 11s 35ms/step - loss: 0.5373 - accuracy: 0.7543 - val_loss: 0.6552 - val_accuracy: 0.5241
# Epoch 23/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.5255 - accuracy: 0.7627 - val_loss: 0.6515 - val_accuracy: 0.5344
# Epoch 24/30
# 313/313 [==============================] - 10s 32ms/step - loss: 0.5145 - accuracy: 0.7728 - val_loss: 0.6459 - val_accuracy: 0.5562
# Epoch 25/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.5045 - accuracy: 0.7802 - val_loss: 0.6334 - val_accuracy: 0.5688
# Epoch 26/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.4951 - accuracy: 0.7877 - val_loss: 0.6283 - val_accuracy: 0.5757
# Epoch 27/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.4859 - accuracy: 0.7949 - val_loss: 0.6277 - val_accuracy: 0.5894
# Epoch 28/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.4773 - accuracy: 0.7998 - val_loss: 0.6302 - val_accuracy: 0.6089
# Epoch 29/30
# 313/313 [==============================] - 11s 36ms/step - loss: 0.4697 - accuracy: 0.8053 - val_loss: 0.6218 - val_accuracy: 0.6089
# Epoch 30/30
# 313/313 [==============================] - 10s 31ms/step - loss: 0.4620 - accuracy: 0.8107 - val_loss: 0.6122 - val_accuracy: 0.6204
# I loved this movie
# [0.502687]
#
#
# that was the worst movie I've ever seen
# [0.29362217]
#
#
# too much violence even for a Bond film
# [0.4684528]
#
#
# a captivating recounting of a cherished myth
# [0.48264673]

# %% [markdown]
# # Use multiple bidirectional LSTMs

# %%
num_epochs = 30

model_multiple_bidi_lstm = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim, 
                                                       return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.0003
model_multiple_bidi_lstm.compile(loss='binary_crossentropy',
                                 optimizer=tf.keras.optimizers.Adam(learning_rate),
                                 metrics=['accuracy'])
fit_model_and_show_results(model_multiple_bidi_lstm, new_reviews)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 50, 16)            64000
#
#  bidirectional_2 (Bidirectio  (None, 50, 32)           4224
#  nal)
#
#  bidirectional_3 (Bidirectio  (None, 32)               6272
#  nal)
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 74,529
# Trainable params: 74,529
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 313/313 [==============================] - 27s 65ms/step - loss: 0.6812 - accuracy: 0.5653 - val_loss: 0.7122 - val_accuracy: 0.5092
# Epoch 2/30
# 313/313 [==============================] - 19s 60ms/step - loss: 0.5001 - accuracy: 0.7527 - val_loss: 0.6727 - val_accuracy: 0.5367
# Epoch 3/30
# 313/313 [==============================] - 19s 60ms/step - loss: 0.3529 - accuracy: 0.8403 - val_loss: 0.7532 - val_accuracy: 0.5287
# Epoch 4/30
# 313/313 [==============================] - 20s 64ms/step - loss: 0.2982 - accuracy: 0.8637 - val_loss: 0.7336 - val_accuracy: 0.4163
# Epoch 5/30
# 313/313 [==============================] - 19s 59ms/step - loss: 0.2659 - accuracy: 0.8809 - val_loss: 0.7592 - val_accuracy: 0.4897
# Epoch 6/30
# 313/313 [==============================] - 19s 60ms/step - loss: 0.2425 - accuracy: 0.8896 - val_loss: 0.7945 - val_accuracy: 0.3979
# Epoch 7/30
# 313/313 [==============================] - 19s 60ms/step - loss: 0.2292 - accuracy: 0.8981 - val_loss: 0.8312 - val_accuracy: 0.5998
# Epoch 8/30
# 313/313 [==============================] - 20s 63ms/step - loss: 0.2142 - accuracy: 0.9008 - val_loss: 0.8159 - val_accuracy: 0.5310
# Epoch 9/30
# 313/313 [==============================] - 19s 60ms/step - loss: 0.2086 - accuracy: 0.9033 - val_loss: 0.8366 - val_accuracy: 0.3865
# Epoch 10/30
# 313/313 [==============================] - 19s 60ms/step - loss: 0.
80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# I loved this movie
# [0.6055673]
#
#
# that was the worst movie I've ever seen
# [0.34330165]
#
#
# too much violence even for a Bond film
# [0.01178935]
#
#
# a captivating recounting of a cherished myth
# [0.98914945]

# %% [markdown]
# # Try some more reviews

# %%
# Write some new reviews 

review1 = """I loved this movie"""

review2 = """that was the worst movie I've ever seen"""

review3 = """too much violence even for a Bond film"""

review4 = """a captivating recounting of a cherished myth"""

review5 = """I saw this movie yesterday and I was feeling low to start with,
 but it was such a wonderful movie that it lifted my spirits and brightened 
 my day, you can\'t go wrong with a movie with Whoopi Goldberg in it."""

review6 = """I don\'t understand why it received an oscar recommendation
 for best movie, it was long and boring"""

review7 = """the scenery was magnificent, the CGI of the dogs was so realistic I
 thought they were played by real dogs even though they talked!"""

review8 = """The ending was so sad and yet so uplifting at the same time. 
 I'm looking for an excuse to see it again"""

review9 = """I had expected so much more from a movie made by the director 
 who made my most favorite movie ever, I was very disappointed in the tedious 
 story"""

review10 = "I wish I could watch this movie every day for the rest of my life"

more_reviews = [review1, review2, review3, review4, review5, review6, review7, 
               review8, review9, review10]

# %%
print("============================\n","Embeddings only:\n", "============================")
predict_review(model, more_reviews)
# Out:
# ============================
#  Embeddings only:
#  ============================
# I loved this movie
# [0.39298257]
#
#
# that was the worst movie I've ever seen
# [0.11397702]
#
#
# too much violence even for a Bond film
# [0.0312542]
#
#
# a captivating recounting of a cherished myth
# [0.59909594]
#
#
# I saw this movie yesterday and I was feeling low to start with,
#  but it was such a wonderful movie that it lifted my spirits and brightened
#  my day, you can't go wrong with a movie with Whoopi Goldberg in it.
# [0.27185166]
#
#
# I don't understand why it received an oscar recommendation
#  for best movie, it was long and boring
# [0.4767337]
#
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
#  thought they were played by real dogs even though they talked!
# [0.26409823]
#
#
# The ending was so sad and yet so uplifting at the same time.
#  I'm looking for an excuse to see it again
# [0.49870977]
#
#
# I had expected so much more from a movie made by the director
#  who made my most favorite movie ever, I was very disappointed in the tedious
#  story
# [0.01120937]
#
#
# I wish I could watch this movie every day for the rest of my life
# [0.30308914]

# %%
print("============================\n","With CNN\n", "============================")
predict_review(model_cnn, more_reviews)
# Out:
# ============================
#  With CNN
#  ============================
# I loved this movie
# [0.89230514]
#
#
# that was the worst movie I've ever seen
# [0.11086819]
#
#
# too much violence even for a Bond film
# [0.00700977]
#
#
# a captivating recounting of a cherished myth
# [0.7688199]
#
#
# I saw this movie yesterday and I was feeling low to start with,
#  but it was such a wonderful movie that it lifted my spirits and brightened
#  my day, you can't go wrong with a movie with Whoopi Goldberg in it.
# [0.31093967]
#
#
# I don't understand why it received an oscar recommendation
#  for best movie, it was long and boring
# [0.86504424]
#
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
#  thought they were played by real dogs even though they talked!
# [0.25383508]
#
#
# The ending was so sad and yet so uplifting at the same time.
#  I'm looking for an excuse to see it again
# [0.5149994]
#
#
# I had expected so much more from a movie made by the director
#  who made my most favorite movie ever, I was very disappointed in the tedious
#  story
# [0.05219838]
#
#
# I wish I could watch this movie every day for the rest of my life
# [0.53094554]

# %%
print("===========================\n","With bidirectional GRU\n", "============================")
predict_review(model_gru, more_reviews)
# Out:
# ===========================
#  With bidirectional GRU
#  ============================
# I loved this movie
# [0.32185858]
#
#
# that was the worst movie I've ever seen
# [0.1261791]
#
#
# too much violence even for a Bond film
# [0.0750429]
#
#
# a captivating recounting of a cherished myth
# [0.5913255]
#
#
# I saw this movie yesterday and I was feeling low to start with,
#  but it was such a wonderful movie that it lifted my spirits and brightened
#  my day, you can't go wrong with a movie with Whoopi Goldberg in it.
# [0.10348359]
#
#
# I don't understand why it received an oscar recommendation
#  for best movie, it was long and boring
# [0.13368365]
#
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
#  thought they were played by real dogs even though they talked!
# [0.11828226]
#
#
# The ending was so sad and yet so uplifting at the same time.
#  I'm looking for an excuse to see it again
# [0.29871386]
#
#
# I had expected so much more from a movie made by the director
#  who made my most favorite movie ever, I was very disappointed in the tedious
#  story
# [0.06790504]
#
#
# I wish I could watch this movie every day for the rest of my life
# [0.17563736]

# %%
print("===========================\n", "With a single bidirectional LSTM:\n", "===========================")
predict_review(model_bidi_lstm, more_reviews)
# Out:
# ===========================
#  With a single bidirectional LSTM:
#  ===========================
# I loved this movie
# [0.502687]
#
#
# that was the worst movie I've ever seen
# [0.29362217]
#
#
# too much violence even for a Bond film
# [0.4684528]
#
#
# a captivating recounting of a cherished myth
# [0.48264673]
#
#
# I saw this movie yesterday and I was feeling low to start with,
#  but it was such a wonderful movie that it lifted my spirits and brightened
#  my day, you can't go wrong with a movie with Whoopi Goldberg in it.
# [0.26037627]
#
#
# I don't understand why it received an oscar recommendation
#  for best movie, it was long and boring
# [0.34083563]
#
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
#  thought they were played by real dogs even though they talked!
# [0.2883981]
#
#
# The ending was so sad and yet so uplifting at the same time.
#  I'm looking for an excuse to see it again
# [0.29790002]
#
#
# I had expected so much more from a movie made by the director
#  who made my most favorite movie ever, I was very disappointed in the tedious
#  story
# [0.22290543]
#
#
# I wish I could watch this movie every day for the rest of my life
# [0.72326314]

# %%
print("===========================\n", "With multiple bidirectional LSTM:\n", "==========================")
predict_review(model_multiple_bidi_lstm, more_reviews)
# Out:
# ===========================
#  With multiple bidirectional LSTM:
#  ==========================
# I loved this movie
# [0.6055673]
#
#
# that was the worst movie I've ever seen
# [0.34330165]
#
#
# too much violence even for a Bond film
# [0.01178935]
#
#
# a captivating recounting of a cherished myth
# [0.98914945]
#
#
# I saw this movie yesterday and I was feeling low to start with,
#  but it was such a wonderful movie that it lifted my spirits and brightened
#  my day, you can't go wrong with a movie with Whoopi Goldberg in it.
# [0.77022254]
#
#
# I don't understand why it received an oscar recommendation
#  for best movie, it was long and boring
# [0.9990798]
#
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
#  thought they were played by real dogs even though they talked!
# [0.97963357]
#
#
# The ending was so sad and yet so uplifting at the same time.
#  I'm looking for an excuse to see it again
# [0.9982922]
#
#
# I had expected so much more from a movie made by the director
#  who made my most favorite movie ever, I was very disappointed in the tedious
#  story
# [0.01026466]
#
#
# I wish I could watch this movie every day for the rest of my life
# [0.01103389]
